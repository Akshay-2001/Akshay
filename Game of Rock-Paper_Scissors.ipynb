# %%
#Rock/Paper/scissors

def replay():
    return input("Do you want to play again (Y/N) : ").lower().startswith('y')

import random

Game = ['Rock', 'Paper', 'Scissors']

Computer_choice = random.choice(Game)

n = Computer_choice

user_score = 0
computer_score = 0
tie = 0

print('Welcome to the Game of Rock - Paper - Scissors')


start = True


while(start) :
    print("\n enter your choice \n")
    player = input(" Rock, Paper, Scissors, Exit :\t")
    x = player.title()
    print(" ")
    if (x == 'Exit') :
        start = False
        break
    elif (x == n) :
        tie += 1
        print(" It's a TIE!")
    elif (x == "Rock") :
        if (n == "Paper") :
            print('Computer Wins! as Paper covers Rock')
            computer_score += 1
        if (n == "Scissors") :
            print('You Wins! as Rock crushes Scissors')
            user_score += 1
    elif (x == "Paper") :
        if (n == "Scissors") :
            print('Computer Wins! as Scissors cuts Paper')
            computer_score += 1
        if (n == "Rock") :
            print('You Wins! as Paper covers Rock')
            user_score += 1  
    elif (x == "Scissors") :
        if (n == "Rock") :
            print('Computer Wins! as Rock crushes Scissors')
            computer_score += 1
        if (n == "Paper") :
            print('You Wins! as Scissors cuts Paper') 
            user_score += 1
    else :
        print("That's not a valid play!")
    
    print(" ")
    print(" ")

    print("Scoreboard : ")
    print("Tie : ", tie)
    print("Player : ", user_score)
    print("Computer : ", computer_score)    
    print(" ")
    print(" ")

print(" ")
print(" ")
print("Thankyou for playing\n")

if (user_score > computer_score) :
    print("Player wins! :) ")
else :
    print("Computer wins! :) ")


print("Do you want to play again ?  ")
replay()
# Out:
# Welcome to the Game of Rock - Paper - Scissors
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	rock
#
# Computer Wins! as Paper covers Rock
#
#
# Scoreboard :
# Tie :  0
# Player :  0
# Computer :  1
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	paper
#
#  It's a TIE!
#
#
# Scoreboard :
# Tie :  1
# Player :  0
# Computer :  1
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	rock
#
# Computer Wins! as Paper covers Rock
#
#
# Scoreboard :
# Tie :  1
# Player :  0
# Computer :  2
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	rock
#
# Computer Wins! as Paper covers Rock
#
#
# Scoreboard :
# Tie :  1
# Player :  0
# Computer :  3
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	paper
#
#  It's a TIE!
#
#
# Scoreboard :
# Tie :  2
# Player :  0
# Computer :  3
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	scissors
#
# You Wins! as Scissors cuts Paper
#
#
# Scoreboard :
# Tie :  2
# Player :  1
# Computer :  3
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	paper
#
#  It's a TIE!
#
#
# Scoreboard :
# Tie :  3
# Player :  1
# Computer :  3
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	rock
#
# Computer Wins! as Paper covers Rock
#
#
# Scoreboard :
# Tie :  3
# Player :  1
# Computer :  4
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	scissors
#
# You Wins! as Scissors cuts Paper
#
#
# Scoreboard :
# Tie :  3
# Player :  2
# Computer :  4
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	rock
#
# Computer Wins! as Paper covers Rock
#
#
# Scoreboard :
# Tie :  3
# Player :  2
# Computer :  5
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	scissors
#
# You Wins! as Scissors cuts Paper
#
#
# Scoreboard :
# Tie :  3
# Player :  3
# Computer :  5
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	scissors
#
# You Wins! as Scissors cuts Paper
#
#
# Scoreboard :
# Tie :  3
# Player :  4
# Computer :  5
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	scissors
#
# You Wins! as Scissors cuts Paper
#
#
# Scoreboard :
# Tie :  3
# Player :  5
# Computer :  5
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	paper
#
#  It's a TIE!
#
#
# Scoreboard :
# Tie :  4
# Player :  5
# Computer :  5
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	paper
#
#  It's a TIE!
#
#
# Scoreboard :
# Tie :  5
# Player :  5
# Computer :  5
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	paper
#
#  It's a TIE!
#
#
# Scoreboard :
# Tie :  6
# Player :  5
# Computer :  5
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	rock
#
# Computer Wins! as Paper covers Rock
#
#
# Scoreboard :
# Tie :  6
# Player :  5
# Computer :  6
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	rock
#
# Computer Wins! as Paper covers Rock
#
#
# Scoreboard :
# Tie :  6
# Player :  5
# Computer :  7
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	scissors
#
# You Wins! as Scissors cuts Paper
#
#
# Scoreboard :
# Tie :  6
# Player :  6
# Computer :  7
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	scissors
#
# You Wins! as Scissors cuts Paper
#
#
# Scoreboard :
# Tie :  6
# Player :  7
# Computer :  7
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	scissors
#
# You Wins! as Scissors cuts Paper
#
#
# Scoreboard :
# Tie :  6
# Player :  8
# Computer :  7
#
#
#
#  enter your choice
#
#  Rock, Paper, Scissors, Exit :	exit
#
#
#
# Thankyou for playing
# Player wins! :)
# Do you want to play again ?
# Do you want to play again (Y/N) : n
# False
